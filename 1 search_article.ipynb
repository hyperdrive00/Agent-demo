# %% [markdown]
# # 使用Web of Science API进行文献DOI文本挖掘
#
# ## 概述
# 本笔记本演示如何使用Web of Science API搜索和提取学术文献数据，特别是文献的DOI信息。我们将通过以下步骤完成整个过程：
#
# 1. **第一步：定义搜索查询** - 构建适合的查询字符串
# 2. **第二步：配置API连接** - 设置API密钥和请求参数
# 3. **第三步：发送API请求** - 向WOS API发送查询请求
# 4. **第四步：解析JSON响应** - 从API响应中提取结构化数据
# 5. **第五步：数据导出** - 将提取的数据保存为Excel文件

# %% [markdown]
# ## 第一步：定义搜索查询
# 首先，我们需要构建一个适合的Web of Science查询字符串。此查询专门搜索关于"阴离子交换膜"的研究文献。
#
# ### 查询字符串构建说明
# - `TI=("anion exchange membrane")`: 搜索标题中包含"阴离子交换膜"的文献
# - `TS=("anion exchange membrane" NOT cataly*)`: 搜索主题中包含"阴离子交换膜"但不包含催化相关词汇的文献
# - `AB=("durability" OR "conductivity" OR "tensile strength" OR "swelling ratio")`: 摘要中包含耐久性、导电性、拉伸强度或溶胀比的文献
# - `PY=(2020-2022)`: 限制发表年份为2020-2022年

# %%
query_string = """
(TI=("anion exchange membrane") OR TS=("anion exchange membrane" NOT cataly*))
AND (AB=("durability" OR "conductivity" OR "tensile strength" OR "swelling ratio"))
AND PY=(2020-2022)
"""

# %% [markdown]
# ## 第二步：配置API连接
# 接下来，我们需要配置Web of Science API的连接参数，包括：
# - **API密钥**：用于身份验证
# - **基础URL**：WOS API的端点地址
# - **请求头**：包含认证信息和接受的数据格式
# - **查询参数**：包括数据库、查询字符串、限制数量、页码和排序字段
#
# ### 重要参数说明
# - `db`: 数据库选择（WOS = Web of Science核心数据库）
# - `q`: 查询字符串（我们在第一步中定义的）
# - `limit`: 每页返回的记录数量（最大100）
# - `page`: 页码（从1开始）
# - `sortField`: 排序字段（LD+D = 按最新日期降序排列）
#
# 在以下链接创建账号并申请权限，获得api key
# https://developer.clarivate.com/apis/wos-starter

# %%
import requests
import logging

# Setup logger
logger = logging.getLogger('wos_TDM.log')
logger.setLevel(logging.INFO)

# API key and query
api_key = "<your_api_key>"
query = query_string
limit = 50
page = 1

# Base URL and headers
base_url = "https://api.clarivate.com/apis/wos-starter/v1/documents"
headers = {
    "accept": "application/json",
    "X-ApiKey": api_key
}

# Request parameters
params = {
    "db": "WOS",
    "q": query,
    "limit": limit,
    "page": page,
    "sortField": "LD+D"
}

# %% [markdown]
# ## 第三步：发送API请求
# 现在我们使用配置好的参数向Web of Science API发送GET请求。代码将：
# 1. 使用`requests.get()`发送HTTP GET请求
# 2. 检查响应状态码（200表示成功）
# 3. 解析JSON响应数据
# 4. 显示总记录数和当前页面的记录数
#
# ### 状态码说明
# - **200**: 请求成功
# - **400**: 请求格式错误
# - **401**: 认证失败（API密钥无效）
# - **403**: 访问被禁止
# - **429**: 请求过于频繁（超过速率限制）

# %%
response = requests.get(base_url, params=params, headers=headers)
if response.status_code == 200:
    logger.info(f"[WOS] Request successful. Status code: {response.status_code}")
    json_data = response.json()
    print(f"Total records: {json_data.get('metadata', {}).get('total', 'Unknown')}")
    print(f"Records in this page: {len(json_data.get('hits', []))}")
else:
    logger.error(f"[WOS] Request failed with status code {response.status_code}. Response content: {response.text}")
# Out:
# Total records: 535
# Records in this page: 50

# %%
response.json()
# Out:
# {'metadata': {'total': 535, 'page': 1, 'limit': 50},
#  'hits': [{'uid': 'WOS:001074351400001',
#    'title': 'Recovery and enrichment of acid from metallurgical wastewater model by electrodialysis integrated diffusion dialysis system using poly(ethylene) based IEMs',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'SEPARATION AND PURIFICATION TECHNOLOGY',
#     'publishYear': 2023,
#     'publishMonth': 'JAN 1',
#     'volume': '304',
#     'articleNumber': '122353',
#     'pages': {'count': 9}},
#    'names': {'authors': [{'displayName': 'Upadhyay, Prashant',
#       'wosStandard': 'Upadhyay, P',
#       'researcherId': 'EBJ-7974-2022'},
#      {'displayName': 'Mishra, Sarthak',
#       'wosStandard': 'Mishra, S',
#       'researcherId': 'HTK-0410-2023'},
#      {'displayName': 'Sharma, Jeet',
#       'wosStandard': 'Sharma, J',
#       'researcherId': 'AAD-2091-2022'},
#      {'displayName': 'Panja, Surajit',
#       'wosStandard': 'Panja, S',
#       'researcherId': 'K-4301-2019'},
#      {'displayName': 'Kulshrestha, Vaibhav',
#       'wosStandard': 'Kulshrestha, V',
#       'researcherId': 'DCH-6145-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001074351400001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001074351400001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001074351400001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001074351400001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 13}],
#    'identifiers': {'doi': '10.1016/j.seppur.2022.122353',
#     'issn': '1383-5866',
#     'eissn': '1873-3794'},
#    'keywords': {'authorKeywords': ['Diffusion dialysis',
#      'Electrodialysis',
#      'Acid recovery',
#      'Proton dialysis coefficient',
#      'Electromembrane process']}},
#   {'uid': 'WOS:001009928800001',
#    'title': 'State-of-the-art and developmental trends in platinum group metal-free cathode catalyst for anion exchange membrane fuel cell (AEMFC)',
#    'types': ['Review'],
#    'sourceTypes': ['Review'],
#    'source': {'sourceTitle': 'APPLIED CATALYSIS B-ENVIRONMENT AND ENERGY',
#     'publishYear': 2023,
#     'publishMonth': 'MAY 15',
#     'volume': '325',
#     'articleNumber': '121733',
#     'pages': {'count': 38}},
#    'names': {'authors': [{'displayName': 'Hossen, Mosaddek',
#       'wosStandard': 'Hossen, M',
#       'researcherId': 'IVI-1699-2023'},
#      {'displayName': 'Hasan, Shamim',
#       'wosStandard': 'Hasan, S',
#       'researcherId': 'EZH-6275-2022'},
#      {'displayName': 'Sardar, Riajul Islam',
#       'wosStandard': 'Sardar, RI',
#       'researcherId': 'IVM-1281-2023'},
#      {'displayName': 'Haider, Jahi bin',
#       'wosStandard': 'Haider, JB',
#       'researcherId': 'IVK-3839-2023'},
#      {'displayName': 'Mottakin, Kaido',
#       'wosStandard': 'Mottakin',
#       'researcherId': 'IVP-7465-2023'},
#      {'displayName': 'Tammeveski, Kaido',
#       'wosStandard': 'Tammeveski, K',
#       'researcherId': 'H-7789-2015'},
#      {'displayName': 'Atanassov, Plamen',
#       'wosStandard': 'Atanassov, P',
#       'researcherId': 'AAI-4242-2020'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001009928800001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001009928800001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001009928800001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:001009928800001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 131}],
#    'identifiers': {'doi': '10.1016/j.apcatb.2022.121733',
#     'issn': '0926-3373',
#     'eissn': '1873-3883'},
#    'keywords': {'authorKeywords': ['Anion',
#      'alkaline exchange membrane fuel cell',
#      'AEMFC',
#      'Oxygen reduction reaction',
#      'ORR',
#      'Hydrogen fuel cell',
#      'H2',
#      'O2',
#      'Non-platinum catalysts',
#      'PGM-free catalysts']}},
#   {'uid': 'WOS:000967455200001',
#    'title': 'High-performance anion exchange membranes achieved by crosslinking two aryl ether-free polymers: poly(bibenzyl <i>N</i>-methyl piperidine) and SEBS',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF MEMBRANE SCIENCE',
#     'publishYear': 2022,
#     'publishMonth': 'DEC 15',
#     'volume': '664',
#     'articleNumber': '121071',
#     'pages': {'count': 11}},
#    'names': {'authors': [{'displayName': 'Min, Kyungwhan',
#       'wosStandard': 'Min, K',
#       'researcherId': 'FNB-7691-2022'},
#      {'displayName': 'Lee, Yerim',
#       'wosStandard': 'Lee, Y',
#       'researcherId': 'FHC-8651-2022'},
#      {'displayName': 'Choi, Yeongeun',
#       'wosStandard': 'Choi, Y',
#       'researcherId': 'IJV-0180-2023'},
#      {'displayName': 'Kwon, Oh Joong',
#       'wosStandard': 'Kwon, OJ',
#       'researcherId': 'KIH-0147-2024'},
#      {'displayName': 'Kim, Tae-Hyun',
#       'wosStandard': 'Kim, TH',
#       'researcherId': 'MXO-1351-2025'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000967455200001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000967455200001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000967455200001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000967455200001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 41}],
#    'identifiers': {'doi': '10.1016/j.memsci.2022.121071',
#     'issn': '0376-7388',
#     'eissn': '1873-3123'},
#    'keywords': {'authorKeywords': ['Anion exchange membranes',
#      'Aryl-ether free polymer backbone',
#      'Phase separation',
#      'Water retention capacity',
#      'Fuel cell and water electrolysis']}},
#   {'uid': 'WOS:000964108100001',
#    'title': 'Towards high alkaline stability and fuel cell performance in anion exchange membranes via backbone-cation alkylene spacer tuning for quaternized poly(biphenylene alkylene)s',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF POWER SOURCES',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 15',
#     'volume': '557',
#     'articleNumber': '232590',
#     'pages': {'count': 10}},
#    'names': {'authors': [{'displayName': 'Wang, Tao',
#       'wosStandard': 'Wang, T',
#       'researcherId': 'JJJ-9995-2023'},
#      {'displayName': 'Zhao, Yu',
#       'wosStandard': 'Zhao, Y',
#       'researcherId': 'EID-6623-2022'},
#      {'displayName': 'Wang, Sheng',
#       'wosStandard': 'Wang, S',
#       'researcherId': 'CIY-7025-2022'},
#      {'displayName': 'Cheng, Sheng',
#       'wosStandard': 'Cheng, S',
#       'researcherId': 'JYZ-4752-2024'},
#      {'displayName': 'Yang, Shanzhong',
#       'wosStandard': 'Yang, SZ',
#       'researcherId': 'HIF-4772-2022'},
#      {'displayName': 'Wei, Haibing',
#       'wosStandard': 'Wei, HB',
#       'researcherId': 'F-3424-2013'},
#      {'displayName': 'Ding, Yunsheng',
#       'wosStandard': 'Ding, YS',
#       'researcherId': 'KJF-9771-2024'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000964108100001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000964108100001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000964108100001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000964108100001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 31}],
#    'identifiers': {'doi': '10.1016/j.jpowsour.2022.232590',
#     'issn': '0378-7753',
#     'eissn': '1873-2755'},
#    'keywords': {'authorKeywords': ['Poly(arylene alkylene)s',
#      'Anion exchange membranes',
#      'Phase separation',
#      'Alkaline stability',
#      'Fuel cells']}},
#   {'uid': 'WOS:000933902300005',
#    'title': 'Probing the effect of ionomer swelling on the stability of anion exchange membrane water electrolyzers',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF POWER SOURCES',
#     'publishYear': 2022,
#     'publishMonth': 'DEC 1',
#     'volume': '550',
#     'articleNumber': '232134',
#     'pages': {'count': 10}},
#    'names': {'authors': [{'displayName': 'Chen, Binyu',
#       'wosStandard': 'Chen, BY',
#       'researcherId': 'EQM-6926-2022'},
#      {'displayName': 'Mardle, Peter',
#       'wosStandard': 'Mardle, P',
#       'researcherId': 'DYZ-4360-2022'},
#      {'displayName': 'Holdcroft, Steven',
#       'wosStandard': 'Holdcroft, S',
#       'researcherId': 'GBF-6339-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000933902300005&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000933902300005&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000933902300005&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000933902300005&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 47}],
#    'identifiers': {'doi': '10.1016/j.jpowsour.2022.232134',
#     'issn': '0378-7753',
#     'eissn': '1873-2755'},
#    'keywords': {'authorKeywords': ['Anion exchange membrane',
#      'Water electrolysis',
#      'Stability',
#      'Ionomer swelling',
#      'HMT-PMBI',
#      'Catalyst coated membrane']}},
#   {'uid': 'WOS:000930674200001',
#    'title': 'Highly Efficient and Durable Anion Exchange Membrane Water Electrolyzer Enabled by a Fe-Ni<sub>3</sub>S<sub>2</sub> Anode Catalyst',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ADVANCED ENERGY AND SUSTAINABILITY RESEARCH',
#     'publishYear': 2023,
#     'publishMonth': 'JAN',
#     'volume': '4',
#     'issue': '1',
#     'pages': {'count': 7}},
#    'names': {'authors': [{'displayName': 'Ding, Guoheng',
#       'wosStandard': 'Ding, GH',
#       'researcherId': 'ESW-1756-2022'},
#      {'displayName': 'Lee, Husileng',
#       'wosStandard': 'Lee, HSL',
#       'researcherId': 'DAC-4711-2022'},
#      {'displayName': 'Li, Zhiheng',
#       'wosStandard': 'Li, ZH',
#       'researcherId': 'LOZ-0497-2024'},
#      {'displayName': 'Du, Jian',
#       'wosStandard': 'Du, J',
#       'researcherId': 'IDL-9445-2023'},
#      {'displayName': 'Wang, Linqin',
#       'wosStandard': 'Wang, LQ',
#       'researcherId': 'LND-1933-2024'},
#      {'displayName': 'Chen, Dexin',
#       'wosStandard': 'Chen, DX',
#       'researcherId': 'LFQ-8197-2024'},
#      {'displayName': 'Sun, Licheng',
#       'wosStandard': 'Sun, LC',
#       'researcherId': 'AAY-7909-2020'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000930674200001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000930674200001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000930674200001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000930674200001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 19}],
#    'identifiers': {'doi': '10.1002/aesr.202200130', 'issn': '2699-9412'},
#    'keywords': {'authorKeywords': ['anion exchange membrane water electrolyzers',
#      'non-noble electrocatalysts',
#      'oxygen evolving reactions']}},
#   {'uid': 'WOS:000917122600001',
#    'title': 'The influence of anion-exchange membrane nanostructure onto ion transport: Adjusting membrane performance through fabrication conditions',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF MEMBRANE SCIENCE',
#     'publishYear': 2023,
#     'publishMonth': 'MAR 5',
#     'volume': '669',
#     'articleNumber': '121306',
#     'pages': {'count': 12}},
#    'names': {'authors': [{'displayName': 'Fischer, Lukas',
#       'wosStandard': 'Fischer, L',
#       'researcherId': 'HGU-8720-2022'},
#      {'displayName': 'Hartmann, Sven Soren',
#       'wosStandard': 'Hartmann, SS',
#       'researcherId': 'HUQ-0873-2023'},
#      {'displayName': 'Maljusch, Artjom',
#       'wosStandard': 'Maljusch, A',
#       'researcherId': 'DDK-3794-2022'},
#      {'displayName': 'Daeschlein, Christian',
#       'wosStandard': 'Däschlein, C',
#       'researcherId': 'CLE-2051-2022'},
#      {'displayName': 'Prymak, Oleg',
#       'wosStandard': 'Prymak, O',
#       'researcherId': 'GFB-7267-2022'},
#      {'displayName': 'Ulbricht, Mathias',
#       'wosStandard': 'Ulbricht, M',
#       'researcherId': 'L-5844-2015'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000917122600001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000917122600001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000917122600001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000917122600001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 13}],
#    'identifiers': {'doi': '10.1016/j.memsci.2022.121306',
#     'issn': '0376-7388',
#     'eissn': '1873-3123'},
#    'keywords': {'authorKeywords': ['Anion-exchange membrane',
#      'Self-assembly',
#      'Ion transport mechanism',
#      'Diffusion dialysis',
#      'Ionic conductivity']}},
#   {'uid': 'WOS:000916228800003',
#    'title': 'Recent developments of membranes and electrocatalysts for the hydrogen production by anion exchange membrane water electrolysers: A review',
#    'types': ['Review'],
#    'sourceTypes': ['Review'],
#    'source': {'sourceTitle': 'ARABIAN JOURNAL OF CHEMISTRY',
#     'publishYear': 2023,
#     'publishMonth': 'FEB',
#     'volume': '16',
#     'issue': '2',
#     'articleNumber': '104451',
#     'pages': {'count': 57}},
#    'names': {'authors': [{'displayName': 'Chand, Kishore',
#       'wosStandard': 'Chand, K',
#       'researcherId': 'AAV-3533-2020'},
#      {'displayName': 'Paladino, Ombretta',
#       'wosStandard': 'Paladino, O',
#       'researcherId': 'DXC-1808-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000916228800003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000916228800003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000916228800003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000916228800003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 39}],
#    'identifiers': {'doi': '10.1016/j.arabjc.2022.104451',
#     'issn': '1878-5352',
#     'eissn': '1878-5379'},
#    'keywords': {'authorKeywords': ['Hydrogen generation',
#      'AEM water electrolysis',
#      'Oxygen evaluation reaction',
#      'Hydrogen evolution reaction',
#      'Membrane electrode assembly',
#      'Ion conductivity']}},
#   {'uid': 'WOS:000921180800001',
#    'title': 'Water transport in anion and proton exchange membranes',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF POWER SOURCES',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 15',
#     'volume': '557',
#     'articleNumber': '232494',
#     'pages': {'count': 15}},
#    'names': {'authors': [{'displayName': 'Wei, Fei',
#       'wosStandard': 'Wei, F',
#       'researcherId': 'EDC-9222-2022'},
#      {'displayName': 'Kosakian, Aslan',
#       'wosStandard': 'Kosakian, A',
#       'researcherId': 'DWC-8616-2022'},
#      {'displayName': 'Liu, Jiafei',
#       'wosStandard': 'Liu, JF',
#       'researcherId': 'DVO-9868-2022'},
#      {'displayName': 'Kracher, James',
#       'wosStandard': 'Kracher, J',
#       'researcherId': 'HMY-0518-2023'},
#      {'displayName': 'Khan, Rafid',
#       'wosStandard': 'Khan, R',
#       'researcherId': 'FZF-0119-2022'},
#      {'displayName': 'Secanell, Marc',
#       'wosStandard': 'Secanell, M',
#       'researcherId': 'GBM-7534-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000921180800001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000921180800001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000921180800001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000921180800001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 6}],
#    'identifiers': {'doi': '10.1016/j.jpowsour.2022.232494',
#     'issn': '0378-7753',
#     'eissn': '1873-2755'},
#    'keywords': {'authorKeywords': ['Anion exchange membrane',
#      'Proton exchange membrane',
#      'Interfacial transport rate',
#      'Desorption',
#      'Activation energy']}},
#   {'uid': 'WOS:000920411400010',
#    'title': 'Tailoring the molecular structure of pyridine-based polymers for enhancing performance of anion exchange electrolyte membranes',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'RENEWABLE ENERGY',
#     'publishYear': 2022,
#     'publishMonth': 'JUL',
#     'volume': '194',
#     'pages': {'range': '366-377', 'begin': '366', 'end': '377', 'count': 12}},
#    'names': {'authors': [{'displayName': 'Xu, Shicheng',
#       'wosStandard': 'Xu, SC',
#       'researcherId': 'JFA-2684-2023'},
#      {'displayName': 'Wu, Wanlong',
#       'wosStandard': 'Wu, WL',
#       'researcherId': 'DUR-0395-2022'},
#      {'displayName': 'Wan, Ruiying',
#       'wosStandard': 'Wan, RY',
#       'researcherId': 'JTY-2008-2023'},
#      {'displayName': 'Wei, Wei',
#       'wosStandard': 'Wei, W',
#       'researcherId': 'IAL-6710-2023'},
#      {'displayName': 'Li, Yujiao',
#       'wosStandard': 'Li, YJ',
#       'researcherId': 'LGC-2136-2024'},
#      {'displayName': 'Wang, Jin',
#       'wosStandard': 'Wang, J',
#       'researcherId': 'JOJ-3477-2023'},
#      {'displayName': 'Sun, Xiaoqi',
#       'wosStandard': 'Sun, XQ',
#       'researcherId': 'KKG-7231-2024'},
#      {'displayName': 'He, Ronghuan',
#       'wosStandard': 'He, RH',
#       'researcherId': 'G-5702-2011'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000920411400010&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000920411400010&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000920411400010&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000920411400010&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 22}],
#    'identifiers': {'doi': '10.1016/j.renene.2022.05.071',
#     'issn': '0960-1481',
#     'eissn': '1879-0682'},
#    'keywords': {'authorKeywords': ['Anion exchange membrane',
#      'Conductivity',
#      'Alkaline stability',
#      'Anion exchange membrane fuel cell',
#      'Aqueous zinc bromine battery']}},
#   {'uid': 'WOS:000911788200002',
#    'title': 'Experimental investigation of anion exchange membrane water electrolysis for a tubular microbial electrosynthesis cell design',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'CATALYSIS COMMUNICATIONS',
#     'publishYear': 2022,
#     'publishMonth': 'OCT',
#     'volume': '170',
#     'articleNumber': '106502',
#     'pages': {'count': 6}},
#    'names': {'authors': [{'displayName': 'Chen, Zhiyuan',
#       'wosStandard': 'Chen, ZY',
#       'researcherId': 'ABQ-8641-2022'},
#      {'displayName': 'Rodriguez, Asier Grijalvo',
#       'wosStandard': 'Rodriguez, AG',
#       'researcherId': 'MPH-6717-2025'},
#      {'displayName': 'Nunez, Pello',
#       'wosStandard': 'Nunez, P',
#       'researcherId': 'HMJ-8559-2023'},
#      {'displayName': 'van Houtven, Diane',
#       'wosStandard': 'van Houtven, D',
#       'researcherId': 'CCZ-6677-2022'},
#      {'displayName': 'Pant, Deepak',
#       'wosStandard': 'Pant, D',
#       'researcherId': 'B-3290-2010'},
#      {'displayName': 'Vaes, Jan',
#       'wosStandard': 'Vaes, J',
#       'researcherId': 'G-3092-2019'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911788200002&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911788200002&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911788200002&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911788200002&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 11}],
#    'identifiers': {'doi': '10.1016/j.catcom.2022.106502',
#     'issn': '1566-7367',
#     'eissn': '1873-3905'},
#    'keywords': {'authorKeywords': ['Hydrogen',
#      'Pressurized reactor',
#      'Membrane electrode assembly',
#      'Tubular electrode']}},
#   {'uid': 'WOS:000914989200001',
#    'title': 'Progress in constructing high-performance anion exchange Membrane: Molecular design, microphase controllability and In-device property',
#    'types': ['Review'],
#    'sourceTypes': ['Review'],
#    'source': {'sourceTitle': 'CHEMICAL ENGINEERING JOURNAL',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 1',
#     'volume': '457',
#     'articleNumber': '141094',
#     'pages': {'count': 15}},
#    'names': {'authors': [{'displayName': 'Yang, Bowen',
#       'wosStandard': 'Yang, BW',
#       'researcherId': 'KCT-5765-2024'},
#      {'displayName': 'Cunman, Zhang',
#       'wosStandard': 'Cunman, Z',
#       'researcherId': 'HLZ-1574-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000914989200001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000914989200001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000914989200001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000914989200001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 57}],
#    'identifiers': {'doi': '10.1016/j.cej.2022.141094',
#     'issn': '1385-8947',
#     'eissn': '1873-3212'},
#    'keywords': {'authorKeywords': ['Anion exchange membrane',
#      'Ionic conductivity',
#      'Alkaline stability',
#      'AEMWE',
#      'AEMFC']}},
#   {'uid': 'WOS:000827728900001',
#    'title': 'Poly(terphenylene) and Bromohexylated Polystyrene-<i>b</i>-poly(ethylene-<i>co</i>-butene)-b-polystyrene Cross-Linked Anion Exchange Membrane with Excellent Comprehensive Performance',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ENERGY & FUELS',
#     'publishYear': 2022,
#     'publishMonth': 'JUL 21',
#     'volume': '36',
#     'issue': '14',
#     'pages': {'range': '7795-7805',
#      'begin': '7795',
#      'end': '7805',
#      'count': 11}},
#    'names': {'authors': [{'displayName': 'Wang, Fanghui',
#       'wosStandard': 'Wang, FH',
#       'researcherId': 'LDM-6440-2024'},
#      {'displayName': 'Li, Conghui',
#       'wosStandard': 'Li, CH',
#       'researcherId': 'JQU-8646-2023'},
#      {'displayName': 'Sang, Jing',
#       'wosStandard': 'Sang, J',
#       'researcherId': 'DPN-6910-2022'},
#      {'displayName': 'Li, Jing',
#       'wosStandard': 'Li, J',
#       'researcherId': 'HKN-1282-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000827728900001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000827728900001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000827728900001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000827728900001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 19}],
#    'identifiers': {'doi': '10.1021/acs.energyfuels.2c01670',
#     'issn': '0887-0624',
#     'eissn': '1520-5029'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000911090200003',
#    'title': 'Side-chain structural engineering on poly(terphenyl piperidinium) anion exchange membrane for water electrolysers',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF MEMBRANE SCIENCE',
#     'publishYear': 2023,
#     'publishMonth': 'JAN 5',
#     'volume': '665',
#     'articleNumber': '121135',
#     'pages': {'count': 11}},
#    'names': {'authors': [{'displayName': 'Liu, Lei',
#       'wosStandard': 'Liu, L',
#       'researcherId': 'IAC-5722-2023'},
#      {'displayName': 'Bai, Li',
#       'wosStandard': 'Bai, L',
#       'researcherId': 'MIW-8112-2025'},
#      {'displayName': 'Liu, Zhiru',
#       'wosStandard': 'Liu, ZR',
#       'researcherId': 'LMP-3967-2024'},
#      {'displayName': 'Miao, Shasha',
#       'wosStandard': 'Miao, SS',
#       'researcherId': 'FLP-8908-2022'},
#      {'displayName': 'Pan, Ji',
#       'wosStandard': 'Pan, J',
#       'researcherId': 'DKE-4181-2022'},
#      {'displayName': 'Shen, Lisha',
#       'wosStandard': 'Shen, LS',
#       'researcherId': 'DTD-6075-2022'},
#      {'displayName': 'Shi, Yan',
#       'wosStandard': 'Shi, Y',
#       'researcherId': 'DSQ-5653-2022'},
#      {'displayName': 'Li, Nanwen',
#       'wosStandard': 'Li, NW',
#       'researcherId': 'D-3836-2011'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911090200003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911090200003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911090200003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000911090200003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 90}],
#    'identifiers': {'doi': '10.1016/j.memsci.2022.121135',
#     'issn': '0376-7388',
#     'eissn': '1873-3123'},
#    'keywords': {'authorKeywords': ['Side chain engineering',
#      'Anion exchange membrane',
#      'Poly(terphenyl piperidinium)',
#      'Water electrolyser',
#      'Alkaline stability']}},
#   {'uid': 'WOS:000905486500001',
#    'title': '<i>In-situ</i> crosslinked, side chain polybenzimidazole-based anion exchange membranes for alkaline direct methanol fuel cells',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'CHEMICAL ENGINEERING JOURNAL',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 15',
#     'volume': '454',
#     'articleNumber': '140046',
#     'pages': {'count': 11}},
#    'names': {'authors': [{'displayName': 'Liu, Guoliang',
#       'wosStandard': 'Liu, GL',
#       'researcherId': 'HGC-3756-2022'},
#      {'displayName': 'Wang, Ailian',
#       'wosStandard': 'Wang, AL',
#       'researcherId': 'JXF-7201-2024'},
#      {'displayName': 'Ji, Wenxi',
#       'wosStandard': 'Ji, WX',
#       'researcherId': 'CXG-0811-2022'},
#      {'displayName': 'Zhang, Fangfang',
#       'wosStandard': 'Zhang, FF',
#       'researcherId': 'HJZ-7780-2023'},
#      {'displayName': 'Wu, Jianing',
#       'wosStandard': 'Wu, JN',
#       'researcherId': 'KBU-4237-2024'},
#      {'displayName': 'Zhang, Taoyi',
#       'wosStandard': 'Zhang, TY',
#       'researcherId': 'JCI-3253-2023'},
#      {'displayName': 'Tang, Haolin',
#       'wosStandard': 'Tang, HL',
#       'researcherId': 'B-9585-2008'},
#      {'displayName': 'Zhang, Haining',
#       'wosStandard': 'Zhang, HN',
#       'researcherId': 'LXB-1038-2024'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000905486500001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000905486500001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000905486500001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000905486500001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 37}],
#    'identifiers': {'doi': '10.1016/j.cej.2022.140046',
#     'issn': '1385-8947',
#     'eissn': '1873-3212'},
#    'keywords': {'authorKeywords': ['In situ crosslinking',
#      'Quaternized polybenzimidazole',
#      'Anion exchange membrane',
#      'Ionic condcutvity',
#      'Alkaline direct methanol fuel cell']}},
#   {'uid': 'WOS:000907794300001',
#    'title': 'Anion exchange membranes and ionomer properties of a polyfluorene-based polymer with alkyl spacers for water electrolysis',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'APPLIED SURFACE SCIENCE',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 1',
#     'volume': '610',
#     'articleNumber': '155601',
#     'pages': {'count': 6}},
#    'names': {'authors': [{'displayName': 'Lim, Haeryang',
#       'wosStandard': 'Lim, H',
#       'researcherId': 'FFQ-9625-2022'},
#      {'displayName': 'Jeong, Insu',
#       'wosStandard': 'Jeong, I',
#       'researcherId': 'MJS-8511-2025'},
#      {'displayName': 'Choi, Jiyong',
#       'wosStandard': 'Choi, J',
#       'researcherId': 'HKZ-3952-2023'},
#      {'displayName': 'Shin, Giwon',
#       'wosStandard': 'Shin, G',
#       'researcherId': 'JSB-2171-2023'},
#      {'displayName': 'Kim, Jeongsu',
#       'wosStandard': 'Kim, J',
#       'researcherId': 'HFD-4218-2022'},
#      {'displayName': 'Kim, Tae-Hyun',
#       'wosStandard': 'Kim, TH',
#       'researcherId': 'MXO-1351-2025'},
#      {'displayName': 'Park, Taiho',
#       'wosStandard': 'Park, T',
#       'researcherId': 'M-9271-2018'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000907794300001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000907794300001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000907794300001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000907794300001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 48}],
#    'identifiers': {'doi': '10.1016/j.apsusc.2022.155601',
#     'issn': '0169-4332',
#     'eissn': '1873-5584'},
#    'keywords': {'authorKeywords': ['Aryl ether-free polymer',
#      'Anion exchange membrane',
#      'Suzuki cross-coupling',
#      'Water electrolysis',
#      'Polyfluorene-based polymer']}},
#   {'uid': 'WOS:000904273900001',
#    'title': 'Further Development of Polyepichlorohydrin Based Anion Exchange Membranes for Reverse Electrodialysis by Tuning Cast Solution Properties',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'MEMBRANES',
#     'publishYear': 2022,
#     'publishMonth': 'DEC',
#     'volume': '12',
#     'issue': '12',
#     'articleNumber': '1192',
#     'pages': {'count': 16}},
#    'names': {'authors': [{'displayName': 'Eti, Mine',
#       'wosStandard': 'Eti, M',
#       'researcherId': 'HLE-4481-2023'},
#      {'displayName': 'Cihanoglu, Aydin',
#       'wosStandard': 'Cihanoglu, A',
#       'researcherId': 'IQW-7599-2023'},
#      {'displayName': 'Guler, Enver',
#       'wosStandard': 'Güler, E',
#       'researcherId': 'C-1589-2015'},
#      {'displayName': 'Gomez-Coma, Lucia',
#       'wosStandard': 'Gomez-Coma, L',
#       'researcherId': 'DUY-6981-2022'},
#      {'displayName': 'Altiok, Esra',
#       'wosStandard': 'Altiok, E',
#       'researcherId': 'HMD-3542-2023'},
#      {'displayName': 'Arda, Muserref',
#       'wosStandard': 'Arda, M',
#       'researcherId': 'AAG-7053-2021'},
#      {'displayName': 'Ortiz, Inmaculada',
#       'wosStandard': 'Ortiz, I',
#       'researcherId': 'K-8570-2014'},
#      {'displayName': 'Kabay, Nalan',
#       'wosStandard': 'Kabay, N',
#       'researcherId': 'JWG-7272-2024'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904273900001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904273900001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904273900001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904273900001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 3}],
#    'identifiers': {'doi': '10.3390/membranes12121192',
#     'eissn': '2077-0375',
#     'pmid': '36557099'},
#    'keywords': {'authorKeywords': ['salinity gradient',
#      'blue energy',
#      'reverse electrodialysis',
#      'anion exchange membrane',
#      'polyepichlorohydrin']}},
#   {'uid': 'WOS:000903543200003',
#    'title': 'Graphene oxide prompted double-crosslinked Poly(vinyl alcohol)/Poly (diallyldimethylammonium chloride) Anion-exchange membrane for superior CO2 electrochemical reduction',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'SEPARATION AND PURIFICATION TECHNOLOGY',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 15',
#     'volume': '307',
#     'articleNumber': '122792',
#     'pages': {'count': 7}},
#    'names': {'authors': [{'displayName': 'Wang, Min',
#       'wosStandard': 'Wang, M',
#       'researcherId': 'GHL-1743-2022'},
#      {'displayName': 'Xu, Bingqing',
#       'wosStandard': 'Xu, BQ',
#       'researcherId': 'KJB-8781-2024'},
#      {'displayName': 'Zou, Qianqian',
#       'wosStandard': 'Zou, QQ',
#       'researcherId': 'HEB-8608-2022'},
#      {'displayName': 'Dong, Xueqi',
#       'wosStandard': 'Dong, XQ',
#       'researcherId': 'MVY-0439-2025'},
#      {'displayName': 'Shao, Rong',
#       'wosStandard': 'Shao, R',
#       'researcherId': 'IOQ-9075-2023'},
#      {'displayName': 'Qiao, Jinli',
#       'wosStandard': 'Qiao, JL',
#       'researcherId': 'JGR-3638-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903543200003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903543200003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903543200003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903543200003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 10}],
#    'identifiers': {'doi': '10.1016/j.seppur.2022.122792',
#     'issn': '1383-5866',
#     'eissn': '1873-3794'},
#    'keywords': {'authorKeywords': ['Anion-exchange membrane',
#      'GO incorporation',
#      'Microregulated 3D inner-porous structure',
#      'Double-crosslinking',
#      'CO2 electroreduction']}},
#   {'uid': 'WOS:000904243100001',
#    'title': 'Fouling behavior of anion-exchange membrane during electrodialysis of biogas slurry: Correlation to applied current',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF WATER PROCESS ENGINEERING',
#     'publishYear': 2022,
#     'publishMonth': 'DEC',
#     'volume': '50',
#     'articleNumber': '103249',
#     'pages': {'count': 8}},
#    'names': {'authors': [{'displayName': 'Xiang, Wenyu',
#       'wosStandard': 'Xiang, WY',
#       'researcherId': 'HHL-6774-2022'},
#      {'displayName': 'Zhou, Buhui',
#       'wosStandard': 'Zhou, BH',
#       'researcherId': 'HKG-9997-2023'},
#      {'displayName': 'Li, Yifan',
#       'wosStandard': 'Li, YF',
#       'researcherId': 'MVT-2913-2025'},
#      {'displayName': 'Yang, Jingru',
#       'wosStandard': 'Yang, JR',
#       'researcherId': 'MHJ-0540-2025'},
#      {'displayName': 'Hu, Bibo',
#       'wosStandard': 'Hu, BB',
#       'researcherId': 'FAZ-0315-2022'},
#      {'displayName': 'Yang, Chun',
#       'wosStandard': 'Yang, C',
#       'researcherId': 'GKN-9438-2022'},
#      {'displayName': 'Li, Xiaobo',
#       'wosStandard': 'Li, XB',
#       'researcherId': 'KDI-1693-2024'},
#      {'displayName': 'He, Daoling',
#       'wosStandard': 'He, DL',
#       'researcherId': 'CUC-7108-2022'},
#      {'displayName': 'Han, Le',
#       'wosStandard': 'Han, L',
#       'researcherId': 'CSH-0601-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904243100001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904243100001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904243100001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000904243100001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 8}],
#    'identifiers': {'doi': '10.1016/j.jwpe.2022.103249', 'issn': '2214-7144'},
#    'keywords': {'authorKeywords': ['Organic fouling',
#      'Ion -exchange membrane',
#      'Fouling indicator',
#      'Biogas slurry',
#      'Valorization']}},
#   {'uid': 'WOS:000903515500001',
#    'title': 'A Review of Recent Chitosan Anion Exchange Membranes for Polymer Electrolyte Membrane Fuel Cells',
#    'types': ['Review'],
#    'sourceTypes': ['Review'],
#    'source': {'sourceTitle': 'MEMBRANES',
#     'publishYear': 2022,
#     'publishMonth': 'DEC',
#     'volume': '12',
#     'issue': '12',
#     'articleNumber': '1265',
#     'pages': {'count': 12}},
#    'names': {'authors': [{'displayName': 'Vijayakumar, Vijayalekshmi',
#       'wosStandard': 'Vijayakumar, V',
#       'researcherId': 'J-5456-2019'},
#      {'displayName': 'Nam, Sang Yong',
#       'wosStandard': 'Nam, SY',
#       'researcherId': 'DUV-0285-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903515500001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903515500001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903515500001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000903515500001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 19}],
#    'identifiers': {'doi': '10.3390/membranes12121265',
#     'eissn': '2077-0375',
#     'pmid': '36557172'},
#    'keywords': {'authorKeywords': ['anion exchange membrane',
#      'biopolymer',
#      'chitosan',
#      'composites',
#      'fuel cell']}},
#   {'uid': 'WOS:000899390300001',
#    'title': 'La-Sr-Co oxide catalysts for oxygen evolution reaction in anion exchange membrane water electrolyzer: The role of electrode fabrication on performance and durability',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'JOURNAL OF POWER SOURCES',
#     'publishYear': 2023,
#     'publishMonth': 'FEB 1',
#     'volume': '556',
#     'articleNumber': '232484',
#     'pages': {'count': 12}},
#    'names': {'authors': [{'displayName': 'Osmieri, Luigi',
#       'wosStandard': 'Osmieri, L',
#       'researcherId': 'I-7790-2019'},
#      {'displayName': 'He, Yanghua',
#       'wosStandard': 'He, YH',
#       'researcherId': 'AAA-3706-2020'},
#      {'displayName': 'Chung, Hoon T.',
#       'wosStandard': 'Chung, HT',
#       'researcherId': 'DTR-5226-2022'},
#      {'displayName': 'McCool, Geoffrey',
#       'wosStandard': 'McCool, G',
#       'researcherId': 'DFV-1102-2022'},
#      {'displayName': 'Zulevi, Barr',
#       'wosStandard': 'Zulevi, B',
#       'researcherId': 'GDN-5233-2022'},
#      {'displayName': 'Cullen, David A.',
#       'wosStandard': 'Cullen, DA',
#       'researcherId': 'A-2918-2015'},
#      {'displayName': 'Zelenay, Piotr',
#       'wosStandard': 'Zelenay, P',
#       'researcherId': 'AEC-7961-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000899390300001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000899390300001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000899390300001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000899390300001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 18}],
#    'identifiers': {'doi': '10.1016/j.jpowsour.2022.232484',
#     'issn': '0378-7753',
#     'eissn': '1873-2755'},
#    'keywords': {'authorKeywords': ['Anion exchange membrane water electrolysis',
#      'Oxygen evolution reaction',
#      'PGM-Free',
#      'Perovskite',
#      'Anion exchange ionomer']}},
#   {'uid': 'WOS:000893443700003',
#    'title': 'Water transport analysis during cathode dry operation of anion exchange membrane water electrolysis',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'INTERNATIONAL JOURNAL OF HYDROGEN ENERGY',
#     'publishYear': 2022,
#     'publishMonth': 'DEC 15',
#     'volume': '47',
#     'issue': '97',
#     'pages': {'range': '40835-40848',
#      'begin': '40835',
#      'end': '40848',
#      'count': 14}},
#    'names': {'authors': [{'displayName': 'Wang, Ruixiang',
#       'wosStandard': 'Wang, RX',
#       'researcherId': 'JEQ-8904-2023'},
#      {'displayName': 'Ohashi, Masato',
#       'wosStandard': 'Ohashi, M',
#       'researcherId': 'DKU-3577-2022'},
#      {'displayName': 'Ishida, Masayoshi',
#       'wosStandard': 'Ishida, M',
#       'researcherId': 'IYS-0068-2023'},
#      {'displayName': 'Ito, Hiroshi',
#       'wosStandard': 'Ito, H',
#       'researcherId': 'L-4367-2018'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000893443700003&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000893443700003&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000893443700003&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000893443700003&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 12}],
#    'identifiers': {'doi': '10.1016/j.ijhydene.2022.09.181',
#     'issn': '0360-3199',
#     'eissn': '1879-3487'},
#    'keywords': {'authorKeywords': ['Anion exchange membrane',
#      'Water electrolysis',
#      'Concentration overpotential',
#      'Dew point',
#      'Water diffusion',
#      'Cathode dry operation']}},
#   {'uid': 'WOS:000897881600001',
#    'title': 'A π-Conjugated Anion-Exchange Membrane with an Ordered Ion-Conducting Channel via the McMurray Coupling Reaction',
#    'types': ['Article', 'Early Access'],
#    'sourceTypes': ['Article', 'Early Access'],
#    'source': {'sourceTitle': 'ANGEWANDTE CHEMIE-INTERNATIONAL EDITION',
#     'publishYear': 2022,
#     'publishMonth': 'DEC 14',
#     'articleNumber': 'e202215017',
#     'pages': {'count': 6}},
#    'names': {'authors': [{'displayName': 'Zhang, Fan',
#       'wosStandard': 'Zhang, F',
#       'researcherId': 'FXU-8650-2022'},
#      {'displayName': 'Zhang, Yang',
#       'wosStandard': 'Zhang, Y',
#       'researcherId': 'ITN-6683-2023'},
#      {'displayName': 'Sun, Lixuan',
#       'wosStandard': 'Sun, LX',
#       'researcherId': 'HGI-1488-2022'},
# ...
#     'publishYear': 2022,
#     'publishMonth': 'NOV 16',
#     'volume': '14',
#     'issue': '45',
#     'pages': {'range': '51212-51221',
#      'begin': '51212',
#      'end': '51221',
#      'count': 10}},
#    'names': {'authors': [{'displayName': 'Xian, Fang',
#       'wosStandard': 'Xian, F',
#       'researcherId': 'IQG-9458-2023'},
#      {'displayName': 'Jia, Lulu',
#       'wosStandard': 'Jia, LL',
#       'researcherId': 'HKV-0715-2023'},
#      {'displayName': 'Sugahara, Yoshiyuki',
#       'wosStandard': 'Sugahara, Y',
#       'researcherId': 'AAT-1129-2021'},
#      {'displayName': 'Xue, Hairong',
#       'wosStandard': 'Xue, HR',
#       'researcherId': 'EGY-5625-2022'},
#      {'displayName': 'Yamauchi, Yusuke',
#       'wosStandard': 'Yamauchi, Y',
#       'researcherId': 'D-2780-2015'},
#      {'displayName': 'Sasaki, Takayoshi',
#       'wosStandard': 'Sasaki, T',
#       'researcherId': 'H-2956-2011'},
#      {'displayName': 'Ma, Renzhi',
#       'wosStandard': 'Ma, RZ',
#       'researcherId': 'E-1749-2011'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000880037800001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000880037800001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000880037800001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000880037800001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 12}],
#    'identifiers': {'doi': '10.1021/acsami.2c15764',
#     'issn': '1944-8244',
#     'eissn': '1944-8252',
#     'pmid': '36322104'},
#    'keywords': {'authorKeywords': ['layered double hydroxide',
#      'nanosheets',
#      'nanoparticles',
#      'building block',
#      'anion-exchange membrane']}},
#   {'uid': 'WOS:000878259000001',
#    'title': 'Performance Characteristics of a Direct Ammonia Fuel Cell with an Anion Exchange Membrane',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ENERGY & FUELS',
#     'publishYear': 2022,
#     'publishMonth': 'NOV 3',
#     'volume': '36',
#     'issue': '21',
#     'pages': {'range': '13203-13211',
#      'begin': '13203',
#      'end': '13211',
#      'count': 9}},
#    'names': {'authors': [{'displayName': 'Liu, Yun',
#       'wosStandard': 'Liu, Y',
#       'researcherId': 'HZI-0944-2023'},
#      {'displayName': 'Pan, Zhefei',
#       'wosStandard': 'Pan, ZF',
#       'researcherId': 'DTG-7034-2022'},
#      {'displayName': 'Esan, Oladapo Christopher',
#       'wosStandard': 'Esan, OC',
#       'researcherId': 'KBR-3373-2024'},
#      {'displayName': 'Xu, Xinhai',
#       'wosStandard': 'Xu, XH',
#       'researcherId': 'J-4037-2014'},
#      {'displayName': 'An, Liang',
#       'wosStandard': 'An, L',
#       'researcherId': 'AFQ-8104-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000878259000001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000878259000001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000878259000001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000878259000001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 33}],
#    'identifiers': {'doi': '10.1021/acs.energyfuels.2c02951',
#     'issn': '0887-0624',
#     'eissn': '1520-5029'},
#    'keywords': {'authorKeywords': []}},
#   {'uid': 'WOS:000877339100001',
#    'title': 'Performance and Stability of Membrane-Electrode Assemblies Using a Carbon-free Connected Pt-Fe Catalyst and Polyphenylene-Based Electrolytes for Direct Formate Anion-Exchange Membrane Fuel Cells',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ACS APPLIED ENERGY MATERIALS',
#     'publishYear': 2022,
#     'publishMonth': 'OCT 20',
#     'volume': '5',
#     'issue': '11',
#     'pages': {'range': '13176-13188',
#      'begin': '13176',
#      'end': '13188',
#      'count': 13}},
#    'names': {'authors': [{'displayName': 'Kuroki, Hidenori',
#       'wosStandard': 'Kuroki, H',
#       'researcherId': 'B-2269-2018'},
#      {'displayName': 'Miyanishi, Shoji',
#       'wosStandard': 'Miyanishi, S',
#       'researcherId': 'F-4702-2015'},
#      {'displayName': 'Tamaki, Takanori',
#       'wosStandard': 'Tamaki, T',
#       'researcherId': 'DXS-5781-2022'},
#      {'displayName': 'Sankar, Sasidharan',
#       'wosStandard': 'Sankar, S',
#       'researcherId': 'V-5413-2017'},
#      {'displayName': 'Anilkumar, Gopinathan M.',
#       'wosStandard': 'Anilkumar, GM',
#       'researcherId': 'DUZ-1512-2022'},
#      {'displayName': 'Arao, Masazumi',
#       'wosStandard': 'Arao, M',
#       'researcherId': 'CED-1327-2022'},
#      {'displayName': 'Shimanuki, Junichi',
#       'wosStandard': 'Shimanuki, J',
#       'researcherId': 'DRN-6807-2022'},
#      {'displayName': 'Matsumoto, Masashi',
#       'wosStandard': 'Matsumoto, M',
#       'researcherId': 'JPA-2812-2023'},
#      {'displayName': 'Imai, Hideto',
#       'wosStandard': 'Imai, H',
#       'researcherId': 'DWI-6524-2022'},
#      {'displayName': 'Yamaguchi, Takeo',
#       'wosStandard': 'Yamaguchi, T',
#       'researcherId': 'H-1607-2011'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877339100001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877339100001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877339100001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877339100001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 3}],
#    'identifiers': {'doi': '10.1021/acsaem.2c01067', 'issn': '2574-0962'},
#    'keywords': {'authorKeywords': ['membrane-electrode assembly',
#      'ether-linkage-free aromatic polyelectrolyte',
#      'connected nanoparticle catalyst',
#      'pore-filling membrane',
#      'liquid fuel',
#      'cryo-TEM']}},
#   {'uid': 'WOS:000873071400001',
#    'title': 'Synthesis of Anion Exchange Membranes Containing PVDF/PES and Either PEI or Fumion®',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'MEMBRANES',
#     'publishYear': 2022,
#     'publishMonth': 'OCT',
#     'volume': '12',
#     'issue': '10',
#     'articleNumber': '959',
#     'pages': {'count': 20}},
#    'names': {'authors': [{'displayName': 'Javier Salazar-Gastelum, Luis',
#       'wosStandard': 'Salazar-Gastelum, LJ',
#       'researcherId': 'FWV-3469-2022'},
#      {'displayName': 'Garcia-Limon, Brenda Yazmin',
#       'wosStandard': 'Garcia-Limon, BY',
#       'researcherId': 'CRW-0587-2022'},
#      {'displayName': 'Lin, Shui Wai',
#       'wosStandard': 'Lin, SW',
#       'researcherId': 'DCB-8133-2022'},
#      {'displayName': 'Cesar Calva-Yanez, Julio',
#       'wosStandard': 'Calva-Yañez, JC',
#       'researcherId': 'JFK-0912-2023'},
#      {'displayName': 'Zizumbo-Lopez, Arturo',
#       'wosStandard': 'Zizumbo-Lopez, A',
#       'researcherId': 'GDR-9005-2022'},
#      {'displayName': 'Romero-Castanon, Tatiana',
#       'wosStandard': 'Romero-Castañón, T',
#       'researcherId': 'JIW-5132-2023'},
#      {'displayName': 'Israel Salazar-Gastelum, Moises',
#       'wosStandard': 'Salazar-Gastelum, MI',
#       'researcherId': 'DQL-2435-2022'},
#      {'displayName': 'Perez-Sicairos, Sergio',
#       'wosStandard': 'Pérez-Sicairos, S',
#       'researcherId': 'GDA-2606-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873071400001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873071400001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873071400001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873071400001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 2}],
#    'identifiers': {'doi': '10.3390/membranes12100959',
#     'eissn': '2077-0375',
#     'pmid': '36295718'},
#    'keywords': {'authorKeywords': ['alkaline fuel cell',
#      'anion exchange membrane',
#      'Fumion (R)',
#      'blended membrane',
#      'phase inversion method',
#      'membrane characterization']}},
#   {'uid': 'WOS:000877309900001',
#    'title': 'High-Capacity Retention Thermally Reinforced Pore-Filled Anion Exchange Membrane for All-Vanadium Flow Batteries',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ACS APPLIED ENERGY MATERIALS',
#     'publishYear': 2022,
#     'publishMonth': 'NOV 28',
#     'volume': '5',
#     'issue': '11',
#     'pages': {'range': '13661-13671',
#      'begin': '13661',
#      'end': '13671',
#      'count': 11}},
#    'names': {'authors': [{'displayName': 'Sreenath, Sooraj',
#       'wosStandard': 'Sreenath, S',
#       'researcherId': 'CDR-4038-2022'},
#      {'displayName': 'Nayanthara, P. S.',
#       'wosStandard': 'Nayanthara, PS',
#       'researcherId': 'FOS-8948-2022'},
#      {'displayName': 'Pawar, Chetan M.',
#       'wosStandard': 'Pawar, CM',
#       'researcherId': 'DMH-7181-2022'},
#      {'displayName': 'Nikumbe, Devendra Y.',
#       'wosStandard': 'Nikumbe, DY',
#       'researcherId': 'HCN-1383-2022'},
#      {'displayName': 'Bhatt, Bhavana',
#       'wosStandard': 'Bhatt, B',
#       'researcherId': 'CET-1936-2022'},
#      {'displayName': 'Chaudhari, Jayesh C.',
#       'wosStandard': 'Chaudhari, JC',
#       'researcherId': 'DVI-8557-2022'},
#      {'displayName': 'Nagarale, Rajaram K.',
#       'wosStandard': 'Nagarale, RK',
#       'researcherId': 'GGQ-7903-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877309900001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877309900001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877309900001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000877309900001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 16}],
#    'identifiers': {'doi': '10.1021/acsaem.2c02328', 'issn': '2574-0962'},
#    'keywords': {'authorKeywords': ['polypropylene',
#      '4-vinyl pyridine',
#      'divinyl benzene',
#      'pore-illed anion exchange membrane',
#      'low swelling ratio',
#      'vanadium redox flow battery',
#      'high-capacity retention']}},
#   {'uid': 'WOS:000873090600001',
#    'title': 'Profiled Ion-Exchange Membranes for Reverse and Conventional Electrodialysis',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'MEMBRANES',
#     'publishYear': 2022,
#     'publishMonth': 'OCT',
#     'volume': '12',
#     'issue': '10',
#     'articleNumber': '985',
#     'pages': {'count': 29}},
#    'names': {'authors': [{'displayName': 'Loza, Sergey',
#       'wosStandard': 'Loza, S',
#       'researcherId': 'D-2717-2019'},
#      {'displayName': 'Loza, Natalia',
#       'wosStandard': 'Loza, N',
#       'researcherId': 'U-4984-2019'},
#      {'displayName': 'Kutenko, Natalia',
#       'wosStandard': 'Kutenko, N',
#       'researcherId': 'ABD-6325-2021'},
#      {'displayName': 'Smyshlyaev, Nikita',
#       'wosStandard': 'Smyshlyaev, N',
#       'researcherId': 'HDE-0787-2022'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873090600001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873090600001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873090600001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000873090600001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 15}],
#    'identifiers': {'doi': '10.3390/membranes12100985',
#     'eissn': '2077-0375',
#     'pmid': '36295744'},
#    'keywords': {'authorKeywords': ['profiled ion-exchange membrane',
#      'reverse electrodialysis',
#      'current-voltage curve',
#      'conductivity',
#      'diffusion permeability',
#      'microheterogeneous model',
#      'selectivity']}},
#   {'uid': 'WOS:000874953700001',
#    'title': 'Fast Hydroxide Conduction via Hydrogen-Bonding Network Confined in Benzimidazolium-Functionalized Covalent Organic Frameworks',
#    'types': ['Article'],
#    'sourceTypes': ['Article'],
#    'source': {'sourceTitle': 'ACS APPLIED MATERIALS & INTERFACES',
#     'publishYear': 2022,
#     'publishMonth': 'SEP 28',
#     'volume': '14',
#     'issue': '38',
#     'pages': {'range': '43861-43867',
#      'begin': '43861',
#      'end': '43867',
#      'count': 7}},
#    'names': {'authors': [{'displayName': 'Wu, Zhenzhen',
#       'wosStandard': 'Wu, ZZ',
#       'researcherId': 'GRN-7688-2022'},
#      {'displayName': 'He, Yanbin',
#       'wosStandard': 'He, YB',
#       'researcherId': 'IST-9346-2023'},
#      {'displayName': 'Liu, Lili',
#       'wosStandard': 'Liu, LL',
#       'researcherId': 'A-6605-2018'},
#      {'displayName': 'Wang, Jing',
#       'wosStandard': 'Wang, J',
#       'researcherId': 'LXQ-6640-2024'},
#      {'displayName': 'Xu, Qinchao',
#       'wosStandard': 'Xu, QC',
#       'researcherId': 'HHN-9931-2022'},
#      {'displayName': 'Zhang, Xian-Ming',
#       'wosStandard': 'Zhang, XM',
#       'researcherId': 'KWJ-9520-2024'},
#      {'displayName': 'Li, Juan',
#       'wosStandard': 'Li, J',
#       'researcherId': 'JEO-6872-2023'}]},
#    'links': {'record': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000874953700001&DestLinkType=FullRecord&DestApp=WOS_CPL',
#     'citingArticles': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000874953700001&DestLinkType=CitingArticles&DestApp=WOS_CPL',
#     'references': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000874953700001&DestLinkType=CitedReferences&DestApp=WOS',
#     'related': 'https://www.webofscience.com/api/gateway?GWVersion=2&SrcApp=pylitsearch2&SrcAuth=WosAPI&KeyUT=WOS:000874953700001&DestLinkType=RelatedRecords&DestApp=WOS_CPL'},
#    'citations': [{'db': 'WOS', 'count': 7}],
#    'identifiers': {'doi': '10.1021/acsami.2c09503',
#     'issn': '1944-8244',
#     'eissn': '1944-8252',
#     'pmid': '36099578'},
#    'keywords': {'authorKeywords': ['hydroxides',
#      'covalent organic frameworks',
#      'benzimidazolium',
#      'hydrogen bond network',
#      'C2 substitutes',
#      'ion conduction']}}]}

# %% [markdown]
# ## 第四步：解析JSON响应
# 在这一步中，我们将原始的JSON响应数据转换为结构化的pandas DataFrame。这包括：
#
# **4.1 提取基本信息**
# - **UID**: 文献唯一标识符
# - **Title**: 文献标题
# - **Type**: 文献类型（期刊论文、会议论文等）
#
# **4.2 提取期刊信息**
# - **Journal**: 期刊名称
# - **Year**: 发表年份
# - **Volume**: 卷号
# - **Issue**: 期号
# - **Pages**: 页码范围
#
# **4.3 提取作者信息**
# - **First_Author**: 第一作者
# - **Author_Count**: 作者总数
# - **All_Authors**: 所有作者列表
#
# **4.4 提取引用和标识符**
# - **Citations**: 被引用次数
# - **DOI**: 数字对象标识符（重要！）
# - **PMID**: PubMed标识符
#
# **4.5 提取关键词和链接**
# - **Keywords**: 作者关键词
# - **WOS_Link**: Web of Science记录链接

# %%
import pandas as pd
import json

def parse_wos_data(data):
    """
    Parse Web of Science API data into a structured DataFrame
    """
    records = []
    
    for hit in data['hits']:
        record = {}
        
        # Basic information
        record['UID'] = hit.get('uid', '')
        record['Title'] = hit.get('title', '')
        record['Type'] = ', '.join(hit.get('types', []))
        
        # Source information
        source = hit.get('source', {})
        record['Journal'] = source.get('sourceTitle', '')
        record['Year'] = source.get('publishYear', '')
        record['Volume'] = source.get('volume', '')
        record['Issue'] = source.get('issue', '')
        record['Pages'] = source.get('pages', {}).get('range', source.get('pages', {}).get('count', ''))
        
        # Authors
        authors = hit.get('names', {}).get('authors', [])
        if authors:
            record['First_Author'] = authors[0].get('displayName', '')
            record['Author_Count'] = len(authors)
            record['All_Authors'] = '; '.join([author.get('displayName', '') for author in authors])
        else:
            record['First_Author'] = ''
            record['Author_Count'] = 0
            record['All_Authors'] = ''
        
        # Citations
        citations = hit.get('citations', [])
        record['Citations'] = citations[0].get('count', 0) if citations else 0
        
        # Identifiers
        identifiers = hit.get('identifiers', {})
        record['DOI'] = identifiers.get('doi', '')
        record['PMID'] = identifiers.get('pmid', '')
        
        # Keywords
        keywords = hit.get('keywords', {}).get('authorKeywords', [])
        record['Keywords'] = '; '.join(keywords) if keywords else ''
        
        # Links
        links = hit.get('links', {})
        record['WOS_Link'] = links.get('record', '')
        
        records.append(record)
    
    return pd.DataFrame(records)

# Parse the data
df = parse_wos_data(json_data)

# Display basic info
print(f"Total records found: {json_data['metadata']['total']}")
print(f"Records in this DataFrame: {len(df)}")
print(f"\\nDataFrame shape: {df.shape}")

# Display the DataFrame
print("\\n" + "="*100)
print("RESEARCH ARTICLES TABLE")
print("="*100)
display(df.head())
# Out:
# Total records found: 535
# Records in this DataFrame: 50
# \nDataFrame shape: (50, 16)
# \n====================================================================================================
# RESEARCH ARTICLES TABLE
# ====================================================================================================
#                    UID                                              Title  \
# 0  WOS:001074351400001  Recovery and enrichment of acid from metallurg...
# 1  WOS:001009928800001  State-of-the-art and developmental trends in p...
# 2  WOS:000967455200001  High-performance anion exchange membranes achi...
# 3  WOS:000964108100001  Towards high alkaline stability and fuel cell ...
# 4  WOS:000933902300005  Probing the effect of ionomer swelling on the ...
#
#       Type                                     Journal  Year Volume Issue  \
# 0  Article      SEPARATION AND PURIFICATION TECHNOLOGY  2023    304
# 1   Review  APPLIED CATALYSIS B-ENVIRONMENT AND ENERGY  2023    325
# 2  Article                 JOURNAL OF MEMBRANE SCIENCE  2022    664
# 3  Article                    JOURNAL OF POWER SOURCES  2023    557
# 4  Article                    JOURNAL OF POWER SOURCES  2022    550
#
#   Pages        First_Author  Author_Count  \
# 0     9  Upadhyay, Prashant             5
# 1    38    Hossen, Mosaddek             7
# 2    11      Min, Kyungwhan             5
# 3    10           Wang, Tao             7
# 4    10         Chen, Binyu             3
#
#                                          All_Authors  Citations  \
# 0  Upadhyay, Prashant; Mishra, Sarthak; Sharma, J...         13
# 1  Hossen, Mosaddek; Hasan, Shamim; Sardar, Riaju...        131
# 2  Min, Kyungwhan; Lee, Yerim; Choi, Yeongeun; Kw...         41
# 3  Wang, Tao; Zhao, Yu; Wang, Sheng; Cheng, Sheng...         31
# 4      Chen, Binyu; Mardle, Peter; Holdcroft, Steven         47
#
#                               DOI PMID  \
# 0    10.1016/j.seppur.2022.122353
# 1    10.1016/j.apcatb.2022.121733
# 2    10.1016/j.memsci.2022.121071
# 3  10.1016/j.jpowsour.2022.232590
# 4  10.1016/j.jpowsour.2022.232134
#
#                                             Keywords  \
# 0  Diffusion dialysis; Electrodialysis; Acid reco...
# 1  Anion; alkaline exchange membrane fuel cell; A...
# 2  Anion exchange membranes; Aryl-ether free poly...
# 3  Poly(arylene alkylene)s; Anion exchange membra...
# 4  Anion exchange membrane; Water electrolysis; S...
#
#                                             WOS_Link
# 0  https://www.webofscience.com/api/gateway?GWVer...
# 1  https://www.webofscience.com/api/gateway?GWVer...
# 2  https://www.webofscience.com/api/gateway?GWVer...
# 3  https://www.webofscience.com/api/gateway?GWVer...
# 4  https://www.webofscience.com/api/gateway?GWVer...

# %% [markdown]
# ## 第五步：数据导出

# %%
# save df to excel
df.to_excel('wos_article_metadata.xlsx', index=False)

# %% [markdown]
# ### 下一步
# 有了以上文献的元数据信息，可以进行简单的筛选和分析。
# 1. **筛选文献**: 可以根据关键词、作者或年份来筛选文献。
# 2. **分析趋势**: 分析不同年份的研究趋势。
# 3. **链接生成**: 使用DOI生成可访问链接（例如：https://doi.org/10.1016/j.jpowsour.2022.232134 ）。
#
# **全文获取路径**
#
# 针对不同需求，全文的获取路径也不同：
#
# - 若仅需摘要：可调用 Web of Science 的 Expand API 或 Crossref 的 API 来获取摘要信息。
#
# - 若需要全文：
#     - API 接口：推荐使用 Elsevier 等出版商提供的官方 API 或文本挖掘 (Text Mining) 接口，这是合规且高效的方式。
#     - 网页抓取：可编写爬虫程序从网页直接获取 HTML 格式的全文，但操作时必须严格遵守目标平台的服务条款和文本挖掘规定。
#     - 备用方案：Sci-Hub 可作为获取 PDF 全文的补充途径，但其数据通常更新至2022年之前。
